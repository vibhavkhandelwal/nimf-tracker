# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import matplotlib.ticker as mtick

# %%
# df = pd.read_csv("data.csv", index_col=0, parse_dates=True)
# df = pd.read_csv("cow-vix.csv", index_col=0, parse_dates=True)
# lme = pd.read_excel("lme.xlsx", index_col=0, parse_dates=True)
# passenger_vehicles = pd.read_csv("passenger-vehicle-13mar.csv", index_col=0, parse_dates=True)
# usd_inr = pd.read_csv("usdinr_sensex.csv", index_col=0, parse_dates=True)
df = pd.read_excel("10y-2y.xlsx", index_col=0, parse_dates=True)

# %%
# passenger_vehicles.dropna(inplace=True)
df = df*100

# %%
usd_inr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/l0/9zb8_rjd2tsghrl0qqtyv4mw0000gn/T/ipykernel_31999/2332023128.py in <module>
# ----> 1 usd_inr
#
# NameError: name 'usd_inr' is not defined

# %%
# df = df.iloc[:,[0,1]]

# %%
ax = df.plot(secondary_y="India 10Y-2Y", figsize=(8,4.5), x_compat=True)

ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=1))
ax.right_ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))

plt.title("Spread between 10Y and 2Y treasury note - USA and India")

ax.grid(visible=False)
plt.grid(visible=False)

# ax.set_xlabel("Lending rate taken as base rate and prime lending rate (as and when applicable)")
ax.set_xlabel("")

ax.legend(loc='lower center', bbox_to_anchor=(0.25, -0.27), fancybox=True, ncol=2)
plt.legend(loc='lower center', bbox_to_anchor=(0.75, -0.27), fancybox=True, ncol=2)

# plt.axhline(y=0, color='k', linestyle='--', alpha=0.3)

# ax.set_ylim(ax.get_ylim()[::-1])

plt.grid(False)

plt.tight_layout()
plt.savefig("cow27mar.png", dpi=250, bbox_inches='tight')

# %%
ax = df.plot(secondary_y="Sensex", figsize=(8,4.5), x_compat=True)

# ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=1))
# ax.right_ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))

plt.title("Indian stock market and INR has been extremely resillient \n despite heightened global volatility")

ax.grid(visible=False)
plt.grid(visible=False)

# ax.set_xlabel("Lending rate taken as base rate and prime lending rate (as and when applicable)")
ax.set_xlabel("")

# ax.legend(loc='lower center', bbox_to_anchor=(0.25, -0.27), fancybox=True, ncol=2)
# plt.legend(loc='lower center', bbox_to_anchor=(0.75, -0.27), fancybox=True, ncol=2)

# plt.axhline(y=0, color='k', linestyle='--', alpha=0.3)

# ax.set_ylim(ax.get_ylim()[::-1])

plt.grid(False)

plt.tight_layout()
plt.savefig("cow20mar.png", dpi=250, bbox_inches='tight')

# %%
df.plot(figsize=(8,4.5), x_compat=True)

plt.title("VIX: USA (CBOE) and India")

plt.grid(visible=False)

# ax.legend(loc='lower center', bbox_to_anchor=(0.25, -0.5), fancybox=True, ncol=2)
# plt.legend(loc='lower center', bbox_to_anchor=(0.75, -0.5), fancybox=True, ncol=2)

# plt.axhline(y=0, color='k', linestyle='--', alpha=0.3)

plt.xlabel("")

plt.grid(False)

plt.tight_layout()
plt.savefig("cow27feb.png", dpi=250, bbox_inches='tight')

# %%
lme.plot(figsize=(8.5,3), x_compat=True)

plt.title("LME Index")

plt.grid(visible=False)

# ax.legend(loc='lower center', bbox_to_anchor=(0.25, -0.5), fancybox=True, ncol=2)
# plt.legend(loc='lower center', bbox_to_anchor=(0.75, -0.5), fancybox=True, ncol=2)

# plt.axhline(y=0, color='k', linestyle='--', alpha=0.3)

plt.xlabel("")

plt.grid(False)

plt.tight_layout()
plt.savefig("com6mar.png", dpi=250, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/l0/9zb8_rjd2tsghrl0qqtyv4mw0000gn/T/ipykernel_31999/3912868630.py in <module>
# ----> 1 lme.plot(figsize=(8.5,3), x_compat=True)
#       2
#       3 plt.title("LME Index")
#       4
#       5 plt.grid(visible=False)
#
# NameError: name 'lme' is not defined

# %%
passenger_vehicles = passenger_vehicles/1000000

# %%
passenger_vehicles.head()
# Out:
#         Passenger Vehicles
# Date
# Mar-17            1.790402
# Apr-17            1.540950
# May-17            1.632369
# Jun-17            1.558202
# Jul-17            1.443317

# %%
(passenger_vehicles.iloc[9:]).plot(figsize=(8,4.5), x_compat=True, marker='.')

plt.title("India passenger vehicles monthly registrations (in Lakhs)")

plt.xlabel("")

plt.grid(False)

plt.tight_layout()
plt.savefig("cow13mar_old.png", dpi=250, bbox_inches='tight')
