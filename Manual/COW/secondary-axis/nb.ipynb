# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import matplotlib.ticker as mtick

# %%
# df = pd.read_csv("data.csv", index_col=0, parse_dates=True)
# df = pd.read_csv("cow-vix.csv", index_col=0, parse_dates=True)
lme = pd.read_excel("lme.xlsx", index_col=0, parse_dates=True)
passenger_vehicles = pd.read_csv("passenger-vehicle-13mar.csv", index_col=0, parse_dates=True)

# %%
passenger_vehicles.dropna(inplace=True)

# %%
df = df.iloc[:,[0,1]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/l0/9zb8_rjd2tsghrl0qqtyv4mw0000gn/T/ipykernel_9348/4262400824.py in <module>
# ----> 1 df = df.iloc[:,[0,1]]
#
# NameError: name 'df' is not defined

# %%
# ax = df.plot(secondary_y="Real lending rate (CPI+WPI based)", figsize=(8,4.5), x_compat=True)

# ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))
# ax.right_ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))

# plt.title("Real lending rate and real credit growth are very low!")

# ax.grid(visible=False)
# plt.grid(visible=False)

# ax.set_xlabel("Lending rate taken as base rate and prime lending rate (as and when applicable)")

# ax.legend(loc='lower center', bbox_to_anchor=(0.25, -0.5), fancybox=True, ncol=2)
# plt.legend(loc='lower center', bbox_to_anchor=(0.75, -0.5), fancybox=True, ncol=2)

# # plt.axhline(y=0, color='k', linestyle='--', alpha=0.3)

# plt.grid(False)

# plt.tight_layout()
# plt.savefig("cow20feb.png", dpi=250, bbox_inches='tight')

# %%
df.plot(figsize=(8,4.5), x_compat=True)

plt.title("VIX: USA (CBOE) and India")

plt.grid(visible=False)

# ax.legend(loc='lower center', bbox_to_anchor=(0.25, -0.5), fancybox=True, ncol=2)
# plt.legend(loc='lower center', bbox_to_anchor=(0.75, -0.5), fancybox=True, ncol=2)

# plt.axhline(y=0, color='k', linestyle='--', alpha=0.3)

plt.xlabel("")

plt.grid(False)

plt.tight_layout()
plt.savefig("cow27feb.png", dpi=250, bbox_inches='tight')

# %%
lme.plot(figsize=(8.5,3), x_compat=True)

plt.title("LME Index")

plt.grid(visible=False)

# ax.legend(loc='lower center', bbox_to_anchor=(0.25, -0.5), fancybox=True, ncol=2)
# plt.legend(loc='lower center', bbox_to_anchor=(0.75, -0.5), fancybox=True, ncol=2)

# plt.axhline(y=0, color='k', linestyle='--', alpha=0.3)

plt.xlabel("")

plt.grid(False)

plt.tight_layout()
plt.savefig("com6mar.png", dpi=250, bbox_inches='tight')

# %%
passenger_vehicles = passenger_vehicles/100000

# %%
passenger_vehicles
# Out:
#         Passenger Vehicles
# Date
# Mar-17            17.90402
# Apr-17            15.40950
# May-17            16.32369
# Jun-17            15.58202
# Jul-17            14.43317
# Aug-17            13.62955
# Sep-17            13.88400
# Oct-17            18.90667
# Nov-17            20.65863
# Dec-17            13.86814
# Jan-18            16.39332
# Feb-18            14.84827
# Mar-18            17.22526
# Apr-18            16.83324
# May-18            18.27806
# Jun-18            16.61410
# Jul-18            16.73921
# Aug-18            15.31040
# Sep-18            14.82501
# Oct-18            16.02083
# Nov-18            20.38916
# Dec-18            17.33833
# Jan-19            16.54563
# Feb-19            14.60593
# Mar-19            16.12230
# Apr-19            15.83724
# May-19            16.76979
# Jun-19            15.65800
# Jul-19            16.42577
# Aug-19            14.81570
# Sep-19            13.60902
# Oct-19            17.12904
# Nov-19            21.06592
# Dec-19            15.26903
# Jan-20            16.04810
# Feb-20            15.64207
# Mar-20            21.02499
# Apr-20             3.44558
# May-20             2.02787
# Jun-20             9.64785
# Jul-20            11.20026
# Aug-20            11.60340
# Sep-20            12.99522
# Oct-20            13.20622
# Nov-20            17.90495
# Dec-20            17.72977
# Jan-21            15.21665
# Feb-21            14.18187
# Mar-21            15.59490
# Apr-21            11.12734
# May-21             5.12221
# Jun-21            11.65038
# Jul-21            14.74174
# Aug-21            13.01084
# Sep-21            12.02621
# Oct-21            12.70171
# Nov-21            17.18438
# Dec-21            14.52866
# Jan-22            13.28427
# Feb-22            12.67889

# %%
(passenger_vehicles.iloc[9:]).plot(figsize=(8,4.5), x_compat=True, marker='.')

plt.title("India passenger vehicles monthly registrations (in Lakhs)")

plt.xlabel("")

plt.grid(False)

plt.tight_layout()
plt.savefig("cow13mar.png", dpi=250, bbox_inches='tight')
