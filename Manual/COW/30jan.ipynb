# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import matplotlib.ticker as mtick

# %%
df = pd.read_excel("30jan.xlsx", index_col=0, parse_dates=True)

# %%
df = df*100

# %%
ax = df.plot(secondary_y="Net exports as % of GDP (inverted scale)", figsize=(8,3.5), x_compat=True)

ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))
ax.right_ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))

ax.grid(visible=False)
plt.grid(visible=False)

plt.title("Macro imbalances have risen (in real terms)")

ax.set_xlabel("GDP (in constant prices) data for FY22 is as per CSO advance estimates")

ax.legend(loc='lower center', bbox_to_anchor=(0.25, -0.5), fancybox=True, ncol=2)
plt.legend(loc='lower center', bbox_to_anchor=(1, -0.5), fancybox=True, ncol=2)


plt.tight_layout()

# %%
df.columns
# Out:
# Index(['Net exports as % of GDP (inverted scale)', 'Exports as % of GDP',
#        'Imports as % of GDP'],
#       dtype='object')

# %%
df.columns = ['Net exports (inverted scale)', 'Exports', 'Imports']

# %%
ax = df.plot(secondary_y="Net exports (inverted scale)", figsize=(8,4), x_compat=True, marker='.')

ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))
ax.right_ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))

ax.grid(visible=False)
plt.grid(visible=False)

plt.title("Macro imbalances have risen (data in % of GDP, in real terms)")

ax.set_xlabel("GDP (in constant prices) data for FY22 is as per CSO advance estimates")

ax.legend(loc='lower center', bbox_to_anchor=(0.25, -0.5), fancybox=True, ncol=2)
plt.legend(loc='lower center', bbox_to_anchor=(0.75, -0.5), fancybox=True, ncol=2)


plt.tight_layout()
plt.savefig("cow30jan.png")
